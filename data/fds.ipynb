# %%
import pandas as pd

# %%
df = pd.read_csv('obd_timeseries.csv')

# %%
df.head()
# Out:
#              timestamp  vehicle_id  engine_rpm  vehicle_speed_kmh  \
# 0  2026-06-14 00:00:00           1     1795.34              11.01
# 1  2026-06-14 00:00:01           1     1711.76              18.97
# 2  2026-06-14 00:00:02           1     1440.93              20.44
# 3  2026-06-14 00:00:03           1     1554.26              10.31
# 4  2026-06-14 00:00:04           1     2167.42              34.95
#
#    coolant_temperature_C  throttle_position_pct  engine_load_pct  \
# 0                  87.05                  22.42            30.87
# 1                  86.66                  14.45            31.48
# 2                  87.17                  14.65            32.97
# 3                  85.85                  16.18            22.56
# 4                  86.81                  11.93            21.81
#
#    fuel_level_pct  battery_voltage  mass_airflow_gps fault_label
# 0           91.54            12.88             45.93     healthy
# ...

# %%
df["fault_label"].value_counts()
# Out:
# fault_label
# healthy         348666
# dropout           2798
# spike             2502
# noise             2387
# sensor_drift      1913
# stuck_at          1734
# Name: count, dtype: int64
